# %%
# %%capture # This removes output

# Installs modules if not yet installed
# !pip install yfinance;
# !pip install alpha_vantage;

# %%
from alpha_vantage.fundamentaldata import FundamentalData
import pandas as pd

# %%
apikey = "L1LKAHT1YOU2TNZP"
fd = FundamentalData(key=apikey, output_format='pandas')
df_is,meta_data_is = fd.get_income_statement_annual(symbol='FCN')
df_bs,meta_data_bs = fd.get_balance_sheet_annual(symbol = 'FCN')
df_cf,meta_data_cf = fd.get_cash_flow_annual(symbol = 'FCN')

# %%
df_is
# Out:
#                               fiscalDateEnding reportedCurrency grossProfit  \
# date
# 1970-01-01 00:00:00.000000000       2020-12-31              USD   788564000
# 1970-01-01 00:00:00.000000001       2019-12-31              USD   817821000
# 1970-01-01 00:00:00.000000002       2018-12-31              USD   699803000
# 1970-01-01 00:00:00.000000003       2017-12-31              USD   592172000
# 1970-01-01 00:00:00.000000004       2016-12-31              USD   599623000
#
#                               totalRevenue costOfRevenue  \
# date
# 1970-01-01 00:00:00.000000000   2461275000    1672711000
# 1970-01-01 00:00:00.000000001   2352717000    1534896000
# 1970-01-01 00:00:00.000000002   2027877000    1328074000
# 1970-01-01 00:00:00.000000003   1807732000    1215560000
# 1970-01-01 00:00:00.000000004   1810394000    1210771000
#
#                               costofGoodsAndServicesSold operatingIncome  \
# date
# ...

# %%
df_bs
# Out:
#                               fiscalDateEnding reportedCurrency totalAssets  \
# date
# 1970-01-01 00:00:00.000000000       2020-12-31              USD  2777363000
# 1970-01-01 00:00:00.000000001       2019-12-31              USD  2783142000
# 1970-01-01 00:00:00.000000002       2018-12-31              USD  2379121000
# 1970-01-01 00:00:00.000000003       2017-12-31              USD  2257241000
# 1970-01-01 00:00:00.000000004       2016-12-31              USD  2225368000
#
#                               totalCurrentAssets  \
# date
# 1970-01-01 00:00:00.000000000         1129707000
# 1970-01-01 00:00:00.000000001         1178661000
# 1970-01-01 00:00:00.000000002          965353000
# 1970-01-01 00:00:00.000000003          794179000
# 1970-01-01 00:00:00.000000004          783171000
#
#                               cashAndCashEquivalentsAtCarryingValue  \
# date
# 1970-01-01 00:00:00.000000000                             294953000
# ...

# %%
df_cf
# Out:
#                               fiscalDateEnding reportedCurrency  \
# date
# 1970-01-01 00:00:00.000000000       2020-12-31              USD
# 1970-01-01 00:00:00.000000001       2019-12-31              USD
# 1970-01-01 00:00:00.000000002       2018-12-31              USD
# 1970-01-01 00:00:00.000000003       2017-12-31              USD
# 1970-01-01 00:00:00.000000004       2016-12-31              USD
#
#                               operatingCashflow  \
# date
# 1970-01-01 00:00:00.000000000         327069000
# 1970-01-01 00:00:00.000000001         217886000
# 1970-01-01 00:00:00.000000002         230672000
# 1970-01-01 00:00:00.000000003         147625000
# 1970-01-01 00:00:00.000000004         233488000
#
#                               paymentsForOperatingActivities  \
# date
# 1970-01-01 00:00:00.000000000                       63827000
# 1970-01-01 00:00:00.000000001                       53685000
# 1970-01-01 00:00:00.000000002                       21687000
# ...

# %%
# Function to convert types
def convert_types(series):
    try:
        return pd.to_datetime(series, errors = 'raise')
    except:
        return pd.to_numeric(series, errors = 'coerce')

df_is_copy = df_is.copy()
df_is_copy.reset_index(inplace = True, drop = True)
df_is_copy = df_is_copy.apply(convert_types, axis = 0)
df_is_copy
# Out:
#   fiscalDateEnding  reportedCurrency  grossProfit  totalRevenue  \
# 0       2020-12-31               NaN    788564000    2461275000
# 1       2019-12-31               NaN    817821000    2352717000
# 2       2018-12-31               NaN    699803000    2027877000
# 3       2017-12-31               NaN    592172000    1807732000
# 4       2016-12-31               NaN    599623000    1810394000
#
#    costOfRevenue  costofGoodsAndServicesSold  operatingIncome  \
# 0     1672711000                  1672711000        282663000
# 1     1534896000                  1534896000        305595000
# 2     1328074000                  1328074000        226005000
# 3     1215560000                  1215560000        108711000
# 4     1210771000                  1210771000        142156000
#
#    sellingGeneralAndAdministrative  researchAndDevelopment  operatingExpenses  \
# 0                        488411000                     NaN          547864000
# ...

# %%
import os
from xlwings.constants import InsertShiftDirection
import xlwings as xw
from datetime import date
import config_data as cfd

model_template = os.path.join(
            os.getcwd(), 'templates\dcf_model_2p_blank.xlsx')

wb = xw.Book(model_template)
asm_sht = wb.sheets['Assumptions']
dcf_sht = wb.sheets['DCF']
fcs_sht = wb.sheets['Forecasts']
is_sht = wb.sheets['IS']
bs_sht = wb.sheets['BS']
cfs_sht = wb.sheets['CFS']
beta_sht = wb.sheets['Beta']
comp_sht = wb.sheets['Comps']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-5af9a2a13ebb> in <module>
#       1 import os
# ----> 2 from xlwings.constants import InsertShiftDirection
#       3 import xlwings as xw
#       4 from datetime import date
#       5 import config_data as cfd
#
# ModuleNotFoundError: No module named 'xlwings'
